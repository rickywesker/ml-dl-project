# %%
from eda_helper import plot_feature_dist

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/train.csv')

# %%
features = df

# %%
features
# Out:
#       Feature1  Feature2  Feature3  Feature4  Feature5  Feature6  Feature7  \
# 0    -3.970049 -2.512336  5.346330 -1.012009  1.844900  0.329840 -0.491590
# 1    -1.195217 -2.839257  3.664059  1.588232  0.853286  0.867530 -0.722809
# 2    -0.292024 -1.351282 -1.738429 -0.342616  2.838636 -0.038033  2.621636
# 3    -0.657196 -2.271627  1.324874 -0.097875  3.637970 -3.413761  0.790723
# 4     1.364217 -1.296612 -0.384658 -0.553006  3.030874 -1.303849  0.501984
# ...        ...       ...       ...       ...       ...       ...       ...
# 3195  1.673063 -1.371783 -1.967652  0.111736  1.612901 -0.118002 -0.356564
# 3196 -2.156864 -1.655429  0.680630  1.499035  0.346765  0.507208  1.584665
# 3197  0.068512 -1.972440 -0.014678 -0.372102  2.473623 -2.943860  5.529861
# 3198 -1.355544  1.188881 -2.895093 -0.384314 -2.467256  1.681962  0.601350
# 3199 -1.245208 -0.679527  1.354301  0.838467  0.126174  0.190773 -2.200126
#
#       Label
# 0         1
# 1         1
# 2         0
# 3         1
# ...

# %%
test_features = pd.read_csv('../data/validation.csv')

# %%
plot_feature_dist(features,test_features)
# Out:
# d:\Apps\conda\envs\ml\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# d:\Apps\conda\envs\ml\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# d:\Apps\conda\envs\ml\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...
