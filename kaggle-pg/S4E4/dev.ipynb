# %%
from autogluon.tabular import TabularDataset, TabularPredictor
import sklearn

# %%
from autogluon.core.metrics import make_scorer

ag_rmsle_scorer = make_scorer(name='RMSLE',
                                 score_func=sklearn.metrics.root_mean_squared_log_error,
                                 optimum=0,
                                 greater_is_better=False)

# %%
sklearn.__version__
# Out:
# '1.4.0'

# %%
train = TabularDataset("train.csv")
test = TabularDataset("test.csv")
label = 'Rings'
#predictor = TabularPredictor.load("../MachinLearningGrading/AutogluonModels/ag-20240417_070035")

# %%
train.drop("id", axis=1, inplace=True)

# %%
train
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Whole weight.1  \
# 0       F   0.550     0.430   0.150        0.7715          0.3285
# 1       F   0.630     0.490   0.145        1.1300          0.4580
# 2       I   0.160     0.110   0.025        0.0210          0.0055
# 3       M   0.595     0.475   0.150        0.9145          0.3755
# 4       I   0.555     0.425   0.130        0.7820          0.3695
# ...    ..     ...       ...     ...           ...             ...
# 90610   M   0.335     0.235   0.075        0.1585          0.0685
# 90611   M   0.555     0.425   0.150        0.8790          0.3865
# 90612   I   0.435     0.330   0.095        0.3215          0.1510
# 90613   I   0.345     0.270   0.075        0.2000          0.0980
# 90614   I   0.425     0.325   0.100        0.3455          0.1525
#
#        Whole weight.2  Shell weight  Rings
# 0              0.1465        0.2400     11
# 1              0.2765        0.3200     11
# 2              0.0030        0.0050      6
# 3              0.2055        0.2500     10
# 4              0.1600        0.1975      9
# ...               ...           ...    ...
# 90610          0.0370        0.0450      6
# 90611          0.1815        0.2400      9
# 90612          0.0785        0.0815      6
# 90613          0.0490        0.0700      6
# 90614          0.0785        0.1050      8
#
# [90615 rows x 9 columns]

# %%
predictor = TabularPredictor(label=label,).fit(train,num_gpus=1,auto_stack=True,presets='best_quality')
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20240418_084924"
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Dynamic stacking is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# Detecting stacked overfitting by sub-fitting AutoGluon on the input data. That is, copies of AutoGluon will be sub-fit on subset(s) of the data. Then, the holdout validation data is used to detect stacked overfitting.
# Sub-fit(s) time limit is: 3600 seconds.
# Starting holdout-based sub-fit for dynamic stacking. Context path is: AutogluonModels/ag-20240418_084924/ds_sub_fit/sub_fit_ho.
# Beginning AutoGluon training ... Time limit = 900s
# AutoGluon will save models to "AutogluonModels/ag-20240418_084924/ds_sub_fit/sub_fit_ho"
# =================== System Info ===================
# AutoGluon Version:  1.0.0
# Python Version:     3.11.8
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 23.3.0: Wed Dec 20 21:31:10 PST 2023; root:xnu-10002.81.5~7/RELEASE_ARM64_T6031
# CPU Count:          16
# Memory Avail:       84.10 GB / 128.00 GB (65.7%)
# Disk Space Avail:   721.28 GB / 926.35 GB (77.9%)
# ===================================================
# Train Data Rows:    80546
# Train Data Columns: 8
# Label Column:       Rings
# Problem Type:       multiclass
# Preprocessing data ...
# Train Data Class Count: 28
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    86128.84 MB
# 	Train Data (Original)  Memory Usage: 8.76 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 7 | ['Length', 'Diameter', 'Height', 'Whole weight', 'Whole weight.1', ...]
# 		('object', []) : 1 | ['Sex']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', []) : 1 | ['Sex']
# 		('float', [])    : 7 | ['Length', 'Diameter', 'Height', 'Whole weight', 'Whole weight.1', ...]
# 	0.1s = Fit runtime
# 	8 features in original data used to generate 8 features in processed data.
# 	Train Data (Processed) Memory Usage: 4.38 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.08s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 110 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 599.8s of the 899.92s of remaining time.
# Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# 	0.3048	 = Validation score   (accuracy)
# 	0.05s	 = Training   runtime
# 	0.47s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 597.67s of the 897.79s of remaining time.
# Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# 	0.2995	 = Validation score   (accuracy)
# 	0.05s	 = Training   runtime
# 	0.46s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 597.14s of the 897.26s of remaining time.
# Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.06%)
# 	0.3706	 = Validation score   (accuracy)
# 	25.08s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 569.05s of the 869.17s of remaining time.
# Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.08%)
# 	0.371	 = Validation score   (accuracy)
# 	50.83s	 = Training   runtime
# 	31.59s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 509.35s of the 809.48s of remaining time.
# Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.08%)
# 	0.3656	 = Validation score   (accuracy)
# 	5.42s	 = Training   runtime
# 	2.42s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 502.59s of the 802.71s of remaining time.
# Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# 	0.3605	 = Validation score   (accuracy)
# 	1.83s	 = Training   runtime
# 	2.01s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 498.1s of the 798.22s of remaining time.
# Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# 	0.3596	 = Validation score   (accuracy)
# 	2.36s	 = Training   runtime
# 	2.15s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 492.95s of the 793.07s of remaining time.
# Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.08%)
# 	0.3627	 = Validation score   (accuracy)
# 	392.69s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 99.22s of the 399.35s of remaining time.
# Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# 	0.3627	 = Validation score   (accuracy)
# 	0.78s	 = Training   runtime
# 	1.77s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 96.01s of the 396.13s of remaining time.
# Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# 	0.3613	 = Validation score   (accuracy)
# 	0.9s	 = Training   runtime
# 	1.96s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 92.43s of the 392.55s of remaining time.
# Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.10%)
# 	0.3706	 = Validation score   (accuracy)
# 	15.5s	 = Training   runtime
# 	2.41s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 75.45s of the 375.57s of remaining time.
# Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.04%)
# 	0.3722	 = Validation score   (accuracy)
# 	36.69s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 37.73s of the 337.85s of remaining time.
# Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.09%)
# 	0.3612	 = Validation score   (accuracy)
# 	14.43s	 = Training   runtime
# 	5.72s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 20.25s of the 320.37s of remaining time.
# Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.08%)
# 	0.3669	 = Validation score   (accuracy)
# 	16.12s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 3.09s of the 303.21s of remaining time.
# Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.04%)
# 	0.3554	 = Validation score   (accuracy)
# 	2.98s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 298.88s of remaining time.
# 	Ensemble Weights: {'NeuralNetTorch_BAG_L1': 0.421, 'NeuralNetFastAI_BAG_L1': 0.211, 'LightGBM_BAG_L1': 0.116, 'XGBoost_BAG_L1': 0.095, 'ExtraTreesGini_BAG_L1': 0.042, 'RandomForestGini_BAG_L1': 0.032, 'LightGBMLarge_BAG_L1': 0.032, 'RandomForestEntr_BAG_L1': 0.021, 'CatBoost_BAG_L1': 0.021, 'ExtraTreesEntr_BAG_L1': 0.011}
# 	0.3748	 = Validation score   (accuracy)
# 	14.53s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting 108 L2 models ...
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 284.23s of the 284.04s of remaining time.
# Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=1.79%)
# 	0.3713	 = Validation score   (accuracy)
# 	46.35s	 = Training   runtime
# 	0.73s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 235.93s of the 235.74s of remaining time.
# Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=2.13%)
# 	0.3674	 = Validation score   (accuracy)
# 	90.63s	 = Training   runtime
# 	2.13s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 142.68s of the 142.5s of remaining time.
# Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=2.11%)
# 	0.3626	 = Validation score   (accuracy)
# 	85.68s	 = Training   runtime
# 	1.7s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 54.8s of the 54.62s of remaining time.
# Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# 	Warning: Reducing model 'n_estimators' from 300 -> 179 due to low time. Expected time usage reduced from 91.7s -> 54.8s...
# 	0.3593	 = Validation score   (accuracy)
# 	18.04s	 = Training   runtime
# 	4.07s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 31.83s of the 31.64s of remaining time.
# Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# 	Warning: Reducing model 'n_estimators' from 300 -> 70 due to low time. Expected time usage reduced from 135.8s -> 31.8s...
# 	0.3447	 = Validation score   (accuracy)
# 	12.52s	 = Training   runtime
# 	1.58s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 17.13s of the 16.94s of remaining time.
# Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=2.21%)
# 	0.3448	 = Validation score   (accuracy)
# 	7.05s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the 4.54s of remaining time.
# 	Ensemble Weights: {'CatBoost_BAG_L2': 0.324, 'NeuralNetFastAI_BAG_L1': 0.162, 'NeuralNetTorch_BAG_L1': 0.162, 'NeuralNetFastAI_BAG_L2': 0.081, 'RandomForestEntr_BAG_L1': 0.054, 'LightGBM_BAG_L2': 0.054, 'LightGBMXT_BAG_L1': 0.027, 'RandomForestGini_BAG_L1': 0.027, 'LightGBMXT_BAG_L2': 0.027, 'RandomForestGini_BAG_L2': 0.027, 'LightGBM_BAG_L1': 0.014, 'XGBoost_BAG_L1': 0.014, 'NeuralNetTorch_r79_BAG_L1': 0.014, 'RandomForestEntr_BAG_L2': 0.014}
# 	0.3753	 = Validation score   (accuracy)
# 	19.08s	 = Training   runtime
# 	0.01s	 = Validation runtime
# AutoGluon training complete, total runtime = 914.69s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20240418_084924/ds_sub_fit/sub_fit_ho")
# Leaderboard on holdout data from dynamic stacking:
#                         model  holdout_score  score_val eval_metric  pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0      NeuralNetFastAI_BAG_L2       0.375310   0.371254    accuracy       12.948312      52.374517  612.054569                 0.595868                0.726671          46.352209            2       True         17
# 1         WeightedEnsemble_L3       0.373026   0.375276    accuracy       14.617764      61.955770  845.048486                 0.009018                0.007149          19.081963            3       True         23
# 2           LightGBMXT_BAG_L2       0.372927   0.367393    accuracy       12.866475      53.780803  656.327477                 0.514030                2.132956          90.625118            2       True         18
# 3       NeuralNetTorch_BAG_L1       0.372132   0.372160    accuracy        0.186635       0.092732   36.685310                 0.186635                0.092732          36.685310            1       True         12
# 4     RandomForestGini_BAG_L2       0.371934   0.359347    accuracy       12.829890      55.717011  583.747309                 0.477445                4.069164          18.044950            2       True         20
# 5         WeightedEnsemble_L2       0.371437   0.374780    accuracy        6.366796      18.885816  510.200998                 0.008770                0.007933          14.529382            2       True         16
# 6      NeuralNetFastAI_BAG_L1       0.369848   0.370608    accuracy        0.584622       0.282749   25.079672                 0.584622                0.282749          25.079672            1       True          3
# 7        CatBoost_r177_BAG_L1       0.369054   0.366896    accuracy        0.074389       0.044234   16.123273                 0.074389                0.044234          16.123273            1       True         14
# 8              XGBoost_BAG_L1       0.368756   0.370596    accuracy        0.690124       2.411881   15.503627                 0.690124                2.411881          15.503627            1       True         11
# 9             LightGBM_BAG_L2       0.368756   0.362625    accuracy       12.768179      53.352187  651.380287                 0.415735                1.704340          85.677928            2       True         19
# 10          LightGBMXT_BAG_L1       0.368557   0.371018    accuracy        5.516074      31.594973   50.825826                 5.516074               31.594973          50.825826            1       True          4
# 11            CatBoost_BAG_L2       0.366968   0.344797    accuracy       12.434778      51.739201  572.748485                 0.082334                0.091354           7.046126            2       True         22
# 12  NeuralNetTorch_r79_BAG_L1       0.365578   0.355375    accuracy        0.276906       0.204193    2.983063                 0.276906                0.204193           2.983063            1       True         15
# 13            LightGBM_BAG_L1       0.364783   0.365630    accuracy        0.488604       2.418393    5.415012                 0.488604                2.418393           5.415012            1       True          5
# 14       LightGBMLarge_BAG_L1       0.364684   0.361197    accuracy        1.276295       5.722591   14.431420                 1.276295                5.722591          14.431420            1       True         13
# 15    RandomForestEntr_BAG_L2       0.363691   0.344735    accuracy       12.523334      53.224136  578.220191                 0.170889                1.576289          12.517832            2       True         21
# 16    RandomForestEntr_BAG_L1       0.363591   0.359559    accuracy        0.760846       2.152168    2.357168                 0.760846                2.152168           2.357168            1       True          7
# 17            CatBoost_BAG_L1       0.363194   0.362724    accuracy        0.108672       0.062267  392.693515                 0.108672                0.062267         392.693515            1       True          8
# 18    RandomForestGini_BAG_L1       0.362598   0.360477    accuracy        0.799567       2.005069    1.826083                 0.799567                2.005069           1.826083            1       True          6
# 19      ExtraTreesGini_BAG_L1       0.362300   0.362662    accuracy        0.720090       1.771317    0.776504                 0.720090                1.771317           0.776504            1       True          9
# 20      ExtraTreesEntr_BAG_L1       0.360810   0.361284    accuracy        0.742571       1.958716    0.903305                 0.742571                1.958716           0.903305            1       True         10
# 21      KNeighborsUnif_BAG_L1       0.312841   0.304795    accuracy        0.059713       0.468157    0.049138                 0.059713                0.468157           0.049138            1       True          1
# 22      KNeighborsDist_BAG_L1       0.306783   0.299469    accuracy        0.067336       0.458406    0.049443                 0.067336                0.458406           0.049443            1       True          2
# Stacked overfitting occurred: False.
# Spend 929 seconds for the sub-fit(s) during dynamic stacking.
# Time left for full fit of AutoGluon: 2671 seconds.
# Starting full fit now with num_stack_levels 1.
# Beginning AutoGluon training ... Time limit = 2671s
# AutoGluon will save models to "AutogluonModels/ag-20240418_084924"
# =================== System Info ===================
# AutoGluon Version:  1.0.0
# Python Version:     3.11.8
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 23.3.0: Wed Dec 20 21:31:10 PST 2023; root:xnu-10002.81.5~7/RELEASE_ARM64_T6031
# CPU Count:          16
# Memory Avail:       83.02 GB / 128.00 GB (64.9%)
# Disk Space Avail:   721.11 GB / 926.35 GB (77.8%)
# ===================================================
# Train Data Rows:    90615
# Train Data Columns: 8
# Label Column:       Rings
# Problem Type:       multiclass
# Preprocessing data ...
# Train Data Class Count: 28
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    85020.80 MB
# 	Train Data (Original)  Memory Usage: 9.85 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 7 | ['Length', 'Diameter', 'Height', 'Whole weight', 'Whole weight.1', ...]
# 		('object', []) : 1 | ['Sex']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', []) : 1 | ['Sex']
# 		('float', [])    : 7 | ['Length', 'Diameter', 'Height', 'Whole weight', 'Whole weight.1', ...]
# 	0.1s = Fit runtime
# 	8 features in original data used to generate 8 features in processed data.
# 	Train Data (Processed) Memory Usage: 4.93 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.09s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 110 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 1780.16s of the 2670.9s of remaining time.
# Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# 	0.3067	 = Validation score   (accuracy)
# 	0.05s	 = Training   runtime
# 	0.51s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 1779.57s of the 2670.31s of remaining time.
# Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# 	0.3017	 = Validation score   (accuracy)
# 	0.05s	 = Training   runtime
# 	0.52s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 1778.96s of the 2669.71s of remaining time.
# Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.06%)
# 	0.3706	 = Validation score   (accuracy)
# 	26.45s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 1751.33s of the 2642.07s of remaining time.
# Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.08%)
# 	0.3703	 = Validation score   (accuracy)
# 	44.61s	 = Training   runtime
# 	39.17s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 1699.23s of the 2589.98s of remaining time.
# Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.08%)
# 	0.3667	 = Validation score   (accuracy)
# 	5.09s	 = Training   runtime
# 	2.09s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 1691.9s of the 2582.64s of remaining time.
# Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# 	0.3605	 = Validation score   (accuracy)
# 	2.01s	 = Training   runtime
# 	2.22s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 1686.95s of the 2577.69s of remaining time.
# Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# 	0.3615	 = Validation score   (accuracy)
# 	2.59s	 = Training   runtime
# 	2.19s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 1681.49s of the 2572.24s of remaining time.
# Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.08%)
# 	0.3645	 = Validation score   (accuracy)
# 	2083.12s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 487.93s of remaining time.
# 	Ensemble Weights: {'NeuralNetFastAI_BAG_L1': 0.413, 'LightGBMXT_BAG_L1': 0.217, 'RandomForestEntr_BAG_L1': 0.152, 'RandomForestGini_BAG_L1': 0.13, 'LightGBM_BAG_L1': 0.065, 'CatBoost_BAG_L1': 0.022}
# 	0.3738	 = Validation score   (accuracy)
# 	10.64s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting 108 L2 models ...
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 477.21s of the 477.11s of remaining time.
# Specified total num_gpus: 1, but only 0 are available. Will use 0 instead
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=1.07%)
# 	0.3728	 = Validation score   (accuracy)
# 	938.55s	 = Training   runtime
# 	0.61s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the -469.82s of remaining time.
# 	Ensemble Weights: {'NeuralNetFastAI_BAG_L2': 0.962, 'LightGBM_BAG_L1': 0.038}
# 	0.373	 = Validation score   (accuracy)
# 	10.89s	 = Training   runtime
# 	0.01s	 = Validation runtime
# AutoGluon training complete, total runtime = 3151.79s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20240418_084924")

# %%
predictor.leaderboard()
# Out:
#                       model  score_val eval_metric  pred_time_val  \
# 0       WeightedEnsemble_L3  -0.184083       RMSLE      12.129352
# 1    NeuralNetFastAI_BAG_L2  -0.184240       RMSLE      12.122948
# 2       WeightedEnsemble_L2  -0.186944       RMSLE       4.896739
# 3    NeuralNetFastAI_BAG_L1  -0.187148       RMSLE       0.321379
# 4   RandomForestGini_BAG_L1  -0.190113       RMSLE       2.323589
# 5   RandomForestEntr_BAG_L1  -0.190456       RMSLE       2.244605
# 6           CatBoost_BAG_L1  -0.192579       RMSLE       0.112025
# 7     ExtraTreesEntr_BAG_L1  -0.197683       RMSLE       2.082329
# 8     ExtraTreesGini_BAG_L1  -0.197818       RMSLE       1.942887
# 9     KNeighborsDist_BAG_L1  -0.211252       RMSLE       0.522200
# 10    KNeighborsUnif_BAG_L1  -0.219191       RMSLE       0.523958
# 11        LightGBMXT_BAG_L1  -0.262023       RMSLE       0.916924
# 12          LightGBM_BAG_L1  -0.315012       RMSLE       0.605426
#
#        fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
# 0   2449.556508                0.006404          11.871436            3
# 1   2437.685072                0.527626        1009.712431            2
# 2     43.776948                0.007166          11.607411            2
# 3     27.530098                0.321379          27.530098            1
# 4      2.015158                2.323589           2.015158            1
# 5      2.624281                2.244605           2.624281            1
# 6   1383.262495                0.112025        1383.262495            1
# 7      0.970308                2.082329           0.970308            1
# 8      0.880103                1.942887           0.880103            1
# 9      0.063767                0.522200           0.063767            1
# 10     0.056576                0.523958           0.056576            1
# 11     5.521015                0.916924           5.521015            1
# 12     5.048840                0.605426           5.048840            1
#
#     can_infer  fit_order
# 0        True         13
# 1        True         12
# 2        True         11
# 3        True          3
# 4        True          6
# 5        True          7
# 6        True          8
# 7        True         10
# 8        True          9
# 9        True          2
# 10       True          1
# 11       True          4
# 12       True          5

# %%
predictor.leaderboard()
# Out:
#                       model  score_val eval_metric  pred_time_val  \
# 0       WeightedEnsemble_L2   0.373801    accuracy      46.042385
# 1       WeightedEnsemble_L3   0.373029    accuracy      47.681648
# 2    NeuralNetFastAI_BAG_L2   0.372808    accuracy      47.675161
# 3    NeuralNetFastAI_BAG_L1   0.370568    accuracy       0.298611
# 4         LightGBMXT_BAG_L1   0.370303    accuracy      39.170374
# 5           LightGBM_BAG_L1   0.366727    accuracy       2.091293
# 6           CatBoost_BAG_L1   0.364531    accuracy       0.064294
# 7   RandomForestEntr_BAG_L1   0.361530    accuracy       2.192798
# 8   RandomForestGini_BAG_L1   0.360481    accuracy       2.218009
# 9     KNeighborsUnif_BAG_L1   0.306704    accuracy       0.512351
# 10    KNeighborsDist_BAG_L1   0.301716    accuracy       0.517533
#
#        fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
# 0   2174.508298                0.007006          10.640719            2
# 1   3113.413801                0.006487          10.890823            3
# 2   3102.522978                0.609898         938.547141            2
# 3     26.451217                0.298611          26.451217            1
# 4     44.610130               39.170374          44.610130            1
# 5      5.085716                2.091293           5.085716            1
# 6   2083.120465                0.064294        2083.120465            1
# 7      2.588978                2.192798           2.588978            1
# 8      2.011073                2.218009           2.011073            1
# 9      0.053654                0.512351           0.053654            1
# 10     0.054604                0.517533           0.054604            1
#
#     can_infer  fit_order
# 0        True          9
# 1        True         11
# 2        True         10
# 3        True          3
# 4        True          4
# 5        True          5
# 6        True          8
# 7        True          7
# 8        True          6
# 9        True          1
# 10       True          2

# %%
res = predictor.predict(test,model="WeightedEnsemble_L2")

# %%
test['Rings'] = res
test[['id', 'Rings']].to_csv("submission2.csv", index=False)
